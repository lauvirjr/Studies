# %% [markdown]
# <a href="https://colab.research.google.com/github/lauvirjr/Studies/blob/main/Integra%C3%A7%C3%A3o_aula_ao_vivo_14_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nomes = ['Paulo','Raphael','Cristiano','Felipe','Mikaely','Fabio','Matheus','ViniciusP','Rahmon','Lauvir','Lucas','ViniciusF','Raphael']
idade = [29,28,46,36,32,25,26,25,26,31,29,28,28]
salario = [10000,1,1,1,20000,1,30000,5000,1,15000,1,3500,1] #nem todos informaram o salário desejado

#for i in range(0,len(idade)):
#  print(f'Nome: {nomes[i]}, Idade: {idade[i]}, Salário {salario[i]}')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize = (18,10))
plt.bar(nomes, idade)
plt.title('Nomes x Idades')
plt.xlabel('Nomes')
plt.ylabel('Idades')
plt.show()

plt.figure(figsize = (17.66,10))
plt.bar(nomes, salario)
plt.title('Nomes x Salário')
plt.xlabel('Nomes')
plt.ylabel('Salários')
plt.show()
